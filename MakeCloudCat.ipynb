# %%
import pandas as pd
import numpy as np
import sys, os
from glob import glob
import xarray as xr
import datetime
import warnings
import gcsfs
import datetime

# %%
# local modules
from myidentify import gsurl2tracks, tracks2version

# %%
# lets put the date here to know when it was last run
date = str(datetime.datetime.now().strftime("%m/%d/%Y, %H:%M:%S"))
print(date)
# Out:
# 01/23/2021, 00:27:19

# %%
# are there extra local drives with new zarr stores? (helps limit the search for new datasets)

mach = os.uname()[1]
if 'haden' in mach:
    local_storage = True
else:
    local_storage = False
    zarr_local = '/d1/naomi/cmip6-zarrs'  # usually matches location in GetSpecified and Requests

# %% [raw]
# # A. Make new noQC catalog
# #    1. Collect listings of all files in GC to make dataframe 'dz_GC'
# #       a. figure out which file listings need to be updated, update and concatenate
# #       b. read in list of zarr stores and turn into df with 8-tuple dataset id
# #    2. read dz_exclude from errata files
# #    3. read in dz_old from old noQC
# #    4. make dz_new with version column from old noQC or finding from tracking_ids
# #    5. using vstore=zstore+version, update dz_new with status, severity and url columns
# #    6. save new noQC catalog and then upload to GC

# %% [raw]
# # B. Make new standard catalog
# #    1. eliminate harmless issues from dz_exclude
# #    2. use this (smaller) list of issues to remove datasets with more serious issues (?) from standard catalog
# #    3. save new standard catalog and then upload to GC

# %%
# A. Make new noQC catalog
#    1. Collect listings of all files in GC to make dataframe 'dz_GC'
#       a. figure out which file listings need to be updated, update and concatenate

if local_storage:
    #new_drives =  ['/net/abbey/a2','/net/abbey/a3','/net/carney/d2','/h120']
    new_drives = ['/net/abbey/a4','/net/carney/d3','/h119','/h121','/h122']

    drives = [s + '/naomi/zarr-minimal' for s in new_drives]
else:
    drives = [zarr_local]  # This must match location in Requests.ipynb or GetSpecified.ipynb

new_drives = list(set(drives))

new_activities=[]
for drive in new_drives:
    dirs = glob(drive+'/*/*')
    for d in dirs:
        new_activities += [d.split('/')[-2]+'/'+d.split('/')[-1]]

new_activities = sorted(list(set(new_activities)))   #. [:2]   # just test a few ***

# override, if necessary:
#new_activities = []

print(new_activities)
# Out:
# ['C4MIP/BCC', 'C4MIP/CCCma', 'C4MIP/CNRM-CERFACS', 'C4MIP/CSIRO', 'C4MIP/IPSL', 'C4MIP/MIROC', 'C4MIP/MOHC', 'C4MIP/MPI-M', 'C4MIP/MRI', 'C4MIP/NASA-GISS', 'C4MIP/NCAR', 'C4MIP/NCC', 'C4MIP/NOAA-GFDL', 'CMIP/AS-RCEC', 'CMIP/AWI', 'CMIP/BCC', 'CMIP/CAMS', 'CMIP/CAS', 'CMIP/CCCR-IITM', 'CMIP/CCCma', 'CMIP/CMCC', 'CMIP/CNRM-CERFACS', 'CMIP/CSIRO', 'CMIP/CSIRO-ARCCSS', 'CMIP/E3SM-Project', 'CMIP/EC-Earth-Consortium', 'CMIP/FIO-QLNM', 'CMIP/HAMMOZ-Consortium', 'CMIP/INM', 'CMIP/IPSL', 'CMIP/KIOST', 'CMIP/MIROC', 'CMIP/MOHC', 'CMIP/MPI-M', 'CMIP/MRI', 'CMIP/NASA-GISS', 'CMIP/NCAR', 'CMIP/NCC', 'CMIP/NIMS-KMA', 'CMIP/NOAA-GFDL', 'CMIP/NUIST', 'CMIP/SNU', 'CMIP/THU', 'CMIP/UA', 'ScenarioMIP/AS-RCEC', 'ScenarioMIP/AWI', 'ScenarioMIP/BCC', 'ScenarioMIP/CAMS', 'ScenarioMIP/CAS', 'ScenarioMIP/CCCR-IITM', 'ScenarioMIP/CCCma', 'ScenarioMIP/CMCC', 'ScenarioMIP/CNRM-CERFACS', 'ScenarioMIP/CSIRO', 'ScenarioMIP/CSIRO-ARCCSS', 'ScenarioMIP/DKRZ', 'ScenarioMIP/DWD', 'ScenarioMIP/E3SM-Project', 'ScenarioMIP/EC-Earth-Consortium', 'ScenarioMIP/FIO-QLNM', 'ScenarioMIP/HAMMOZ-Consortium', 'ScenarioMIP/INM', 'ScenarioMIP/IPSL', 'ScenarioMIP/KIOST', 'ScenarioMIP/MIROC', 'ScenarioMIP/MOHC', 'ScenarioMIP/MPI-M', 'ScenarioMIP/MRI', 'ScenarioMIP/NASA-GISS', 'ScenarioMIP/NCAR', 'ScenarioMIP/NCC', 'ScenarioMIP/NIMS-KMA', 'ScenarioMIP/NOAA-GFDL', 'ScenarioMIP/NUIST', 'ScenarioMIP/THU']

# %%
fs = gcsfs.GCSFileSystem(token='anon',access='read_only',cache_timeout=-1)

for activity_id in new_activities:
    print(activity_id)
    aname = activity_id.replace('/','-')
    GCfile = f'GC/GC_files_{aname}.txt'
    try:
        flist = fs.glob(f'gs://cmip6/{activity_id}/**/.zmetadata')
        with open(GCfile, "w") as file:
            file.write('\n'.join(flist))    
    except:
        print(f'skipping {activity_id}')
        continue
# Out:
# C4MIP/BCC
# C4MIP/CCCma
# C4MIP/CNRM-CERFACS
# C4MIP/CSIRO
# C4MIP/IPSL
# C4MIP/MIROC
# C4MIP/MOHC
# C4MIP/MPI-M
# C4MIP/MRI
# C4MIP/NASA-GISS
# C4MIP/NCAR
# C4MIP/NCC
# C4MIP/NOAA-GFDL
# CMIP/AS-RCEC
# CMIP/AWI
# CMIP/BCC
# CMIP/CAMS
# CMIP/CAS
# CMIP/CCCR-IITM
# CMIP/CCCma
# CMIP/CMCC
# CMIP/CNRM-CERFACS
# CMIP/CSIRO
# CMIP/CSIRO-ARCCSS
# CMIP/E3SM-Project
# CMIP/EC-Earth-Consortium
# CMIP/FIO-QLNM
# CMIP/HAMMOZ-Consortium
# CMIP/INM
# CMIP/IPSL
# CMIP/KIOST
# CMIP/MIROC
# CMIP/MOHC
# CMIP/MPI-M
# CMIP/MRI
# CMIP/NASA-GISS
# CMIP/NCAR
# CMIP/NCC
# CMIP/NIMS-KMA
# CMIP/NOAA-GFDL
# CMIP/NUIST
# CMIP/SNU
# CMIP/THU
# CMIP/UA
# ScenarioMIP/AS-RCEC
# ScenarioMIP/AWI
# ScenarioMIP/BCC
# ScenarioMIP/CAMS
# ScenarioMIP/CAS
# ScenarioMIP/CCCR-IITM
# ScenarioMIP/CCCma
# ScenarioMIP/CMCC
# ScenarioMIP/CNRM-CERFACS
# ScenarioMIP/CSIRO
# ScenarioMIP/CSIRO-ARCCSS
# ScenarioMIP/DKRZ
# ScenarioMIP/DWD
# ScenarioMIP/E3SM-Project
# ScenarioMIP/EC-Earth-Consortium
# ScenarioMIP/FIO-QLNM
# ScenarioMIP/HAMMOZ-Consortium
# ScenarioMIP/INM
# ScenarioMIP/IPSL
# ScenarioMIP/KIOST
# ScenarioMIP/MIROC
# ScenarioMIP/MOHC
# ScenarioMIP/MPI-M
# ScenarioMIP/MRI
# ScenarioMIP/NASA-GISS
# ScenarioMIP/NCAR
# ScenarioMIP/NCC
# ScenarioMIP/NIMS-KMA
# ScenarioMIP/NOAA-GFDL
# ScenarioMIP/NUIST
# ScenarioMIP/THU

# %%
# A. Make new noQC catalog
#    1. Collect listings of all files in GC to make dataframe 'dz_GC'
#       b. read in list of zarr stores and turn into df with 8-tuple dataset id

GCfiles = sorted(glob('GC/GC_files_*.txt'))
files = []
for GCfile in GCfiles:
    with open(GCfile, "r") as file:
        files += file.read().split('\n')

ddict = {}
for item, tdir in enumerate(files):
    #store = tdir.split('.zmetadata')[0]
    store = 'gs://'+ tdir.split('.zmetadata')[0]
    vlist = tdir.split('/')[-9:-1]
    if vlist[-2] == vlist[-1]:
        print('must fix:',tdir)
        assert False
        
    vlist += [store]
    ddict[item] = vlist

dz_GC = pd.DataFrame.from_dict(ddict, orient='index')
dz_GC = dz_GC.rename(columns={0: "activity_id", 1: "institution_id", 2:"source_id",
                        3:"experiment_id",4:"member_id",5:"table_id",6:"variable_id",
                        7:"grid_label",8:"zstore"}) 

dz_GC["dcpp_init_year"] = dz_GC.member_id.map(lambda x: float(x.split("-")[0][1:] if x.startswith("s") else np.nan))
dz_GC["member_id"] = dz_GC["member_id"].map(lambda x: x.split("-")[-1] if x.startswith("s") else x)

# %%
# A. Make new noQC catalog
#    2. read dz_exclude from errata files

dz_exclude = pd.read_csv('csv/errata-files.csv')
dz_exclude['zstore'] = ['gs://cmip6/' + s.split('CMIP6.')[-1][:-9].replace('.','/') \
                        + '/' for s in dz_exclude.file_id]
dz_exclude['vstore'] = dz_exclude.apply(lambda row: row.zstore + 'v' + str(row.version), axis = 1)
len(dz_exclude)
# Out:
# /usr/local/python/anaconda3/envs/pangeo-fall2020/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# 164212

# %%
# A. Make new noQC catalog
#    3. read in dz_old from old noQC to get known versions from old catalog

dz_old = pd.read_csv('https://cmip6.storage.googleapis.com/cmip6-zarr-consolidated-stores-noQC.csv', dtype='unicode')
dz_new = pd.merge(dz_GC, dz_old[['zstore','version']], on='zstore', how='left', sort=False)

# %%
# A. 
#   4a. update version if store has been replaced by a newer version

df_newversions = pd.read_csv('csv/newversions.csv', dtype='unicode')

for index, row in df_newversions.iterrows():
    zstore = row.zstore
    newver = row.version
    #print(index,zstore,newver)
    oldver = dz_new[dz_new.zstore==zstore].version.values[0] 
    #print(oldver,newver)
    if newver == oldver:
        ver = oldver
    else:
        #print(newver,oldver)
        ver = newver
    dz_new.loc[dz_new.zstore == zstore,'version'] = newver

# %%
### try write using list comprehension

# A. Make new noQC catalog
#    4b. fix ambiguous or missing versions in dz_new

version = []

for index, row in dz_new.iterrows():
    zstore = row.zstore
    ver = row.version           
    if ver == 'ambiguous' or pd.isna(ver):
        try:
            tracks = gsurl2tracks(zstore)
            (newver,jdict) = tracks2version(tracks,verbose=False)
            #print(ver,newver)
            ver = newver
        except:
            print('trouble determining version for ',zstore)
            ver = 'ambiguous'
        
    version += [ver]

dz_new['version'] = version
# Out:
# /home/naomi/BigRewrite/myidentify.py:61: UserWarning: multiple dataset_ids correspond to the dataset tracking_ids!
# hdl:21.14100
#   warnings.warn(f'multiple dataset_ids correspond to the dataset tracking_ids!\n{ds_tracking_id}')
# /home/naomi/BigRewrite/myidentify.py:61: UserWarning: multiple dataset_ids correspond to the dataset tracking_ids!
# hdl:21.14100/c36114a7-d52c-3a85-8c23-0f697add0e76;hdl:21.14100/a8141482-d32a-3518-aea1-1078427a8a87
#   warnings.warn(f'multiple dataset_ids correspond to the dataset tracking_ids!\n{ds_tracking_id}')
# /home/naomi/BigRewrite/myidentify.py:61: UserWarning: multiple dataset_ids correspond to the dataset tracking_ids!
# hdl:21.14100/a3670dcc-a5ef-3528-b260-9d941e696e64;hdl:21.14100/3bd8bb1b-da5c-3277-8d14-596ed33f2329
#   warnings.warn(f'multiple dataset_ids correspond to the dataset tracking_ids!\n{ds_tracking_id}')
# /home/naomi/BigRewrite/myidentify.py:61: UserWarning: multiple dataset_ids correspond to the dataset tracking_ids!
# hdl:21.14100/27971ee9-e1a1-365e-b4b9-7a2178d05561;hdl:21.14100/9e97fdf5-9eae-373b-b14b-317e9b6cf6dd
#   warnings.warn(f'multiple dataset_ids correspond to the dataset tracking_ids!\n{ds_tracking_id}')
# /home/naomi/BigRewrite/myidentify.py:61: UserWarning: multiple dataset_ids correspond to the dataset tracking_ids!
# hdl:21.14100/f86cb414-aba4-34f3-8892-bf6006efaff4;hdl:21.14100/475c8fd5-a1e9-3342-ac9d-ca45ea674c46
#   warnings.warn(f'multiple dataset_ids correspond to the dataset tracking_ids!\n{ds_tracking_id}')
# /home/naomi/BigRewrite/myidentify.py:61: UserWarning: multiple dataset_ids correspond to the dataset tracking_ids!
# hdl:21.14100/de956f50-475a-3bc6-9e0e-3b140e62437a;hdl:21.14100/3f7f6205-77ab-3b2e-af29-769fc5cb8706
#   warnings.warn(f'multiple dataset_ids correspond to the dataset tracking_ids!\n{ds_tracking_id}')
# /home/naomi/BigRewrite/myidentify.py:61: UserWarning: multiple dataset_ids correspond to the dataset tracking_ids!
# hdl:21.14100/88ca1d4c-86e2-3ace-84c9-b9474733c3b9;hdl:21.14100/72c41346-9c2c-3cac-8145-fe393a907128
#   warnings.warn(f'multiple dataset_ids correspond to the dataset tracking_ids!\n{ds_tracking_id}')
# /home/naomi/BigRewrite/myidentify.py:94: UserWarning:
#
# *** Errata exists, see: https://errata.es-doc.org/static/view.html?uid=61c9b180-7b43-bb52-a53d-8b498d0aa58e
#
#   warnings.warn(f'\n\n*** Errata exists, see: https://errata.es-doc.org/static/view.html?uid={eid}\n')
# /home/naomi/BigRewrite/myidentify.py:94: UserWarning:
#
# *** Errata exists, see: https://errata.es-doc.org/static/view.html?uid=61c9b180-7b43-bb52-a53d-8b498d0aa58e
#
#   warnings.warn(f'\n\n*** Errata exists, see: https://errata.es-doc.org/static/view.html?uid={eid}\n')
# /home/naomi/BigRewrite/myidentify.py:33: UserWarning:
#
# netcdf file tracking_ids are NOT UNIQUE!
# ['hdl:21.14100/70eaff4c-e4f2-4243-98db-5bd0a18c3bf1', 'hdl:21.14100/70eaff4c-e4f2-4243-98db-5bd0a18c3bf1', 'hdl:21.14100/70eaff4c-e4f2-4243-98db-5bd0a18c3bf1', 'hdl:21.14100/70eaff4c-e4f2-4243-98db-5bd0a18c3bf1']
#
#   warnings.warn("\n" + msg)
# /home/naomi/BigRewrite/myidentify.py:33: UserWarning:
#
# netcdf file tracking_ids are NOT UNIQUE!
# ['hdl:21.14100/bce696ab-a714-4aff-9ddf-692071933ca6', 'hdl:21.14100/bce696ab-a714-4aff-9ddf-692071933ca6', 'hdl:21.14100/bce696ab-a714-4aff-9ddf-692071933ca6', 'hdl:21.14100/bce696ab-a714-4aff-9ddf-692071933ca6']
#
#   warnings.warn("\n" + msg)
# /home/naomi/BigRewrite/myidentify.py:33: UserWarning:
#
# netcdf file tracking_ids are NOT UNIQUE!
# ['hdl:21.14100/42b42cf7-c860-4c4f-92f1-0711b60ca9a5', 'hdl:21.14100/42b42cf7-c860-4c4f-92f1-0711b60ca9a5', 'hdl:21.14100/42b42cf7-c860-4c4f-92f1-0711b60ca9a5', 'hdl:21.14100/42b42cf7-c860-4c4f-92f1-0711b60ca9a5']
#
#   warnings.warn("\n" + msg)
# /home/naomi/BigRewrite/myidentify.py:33: UserWarning:
#
# netcdf file tracking_ids are NOT UNIQUE!
# ['hdl:21.14100/87aa7b48-34d0-4368-ab01-3f2fe33161d5', 'hdl:21.14100/87aa7b48-34d0-4368-ab01-3f2fe33161d5', 'hdl:21.14100/87aa7b48-34d0-4368-ab01-3f2fe33161d5', 'hdl:21.14100/87aa7b48-34d0-4368-ab01-3f2fe33161d5']
#
#   warnings.warn("\n" + msg)
# /home/naomi/BigRewrite/myidentify.py:87: UserWarning:
#
# *** Newer version exists, see: http://hdl.handle.net/hdl:21.14100
#   warnings.warn(f'multiple dataset_ids correspond to the dataset tracking_ids!\n{ds_tracking_id}')
# /home/naomi/BigRewrite/myidentify.py:61: UserWarning: multiple dataset_ids correspond to the dataset tracking_ids!
# hdl:21.14100/dea085be-23e9-38eb-9743-82da48a9eda5;hdl:21.14100/3a703948-e4c8-3c8e-a64b-aacfc8ef9046;hdl:21.14100/a81c2a5a-c52d-3b6a-be6a-17d97561ca71
#   warnings.warn(f'multiple dataset_ids correspond to the dataset tracking_ids!\n{ds_tracking_id}')
# /home/naomi/BigRewrite/myidentify.py:61: UserWarning: multiple dataset_ids correspond to the dataset tracking_ids!
# hdl:21.14100/e4f4561c-babb-3e9e-b5d6-8820bbf40054;hdl:21.14100/9b654994-3b33-31a8-a3dc-62ed16baa712
#   warnings.warn(f'multiple dataset_ids correspond to the dataset tracking_ids!\n{ds_tracking_id}')
# /home/naomi/BigRewrite/myidentify.py:94: UserWarning:
#
# *** Errata exists, see: https://errata.es-doc.org/static/view.html?uid=54c5acfd-f459-aa02-b878-2ba024cf9168
#
#   warnings.warn(f'\n\n*** Errata exists, see: https://errata.es-doc.org/static/view.html?uid={eid}\n')
# /home/naomi/BigRewrite/myidentify.py:94: UserWarning:
#
# *** Errata exists, see: https://errata.es-doc.org/static/view.html?uid=3bf9b559-e9e8-2471-9a8b-3b580296abbf
#
#   warnings.warn(f'\n\n*** Errata exists, see: https://errata.es-doc.org/static/view.html?uid={eid}\n')
# /home/naomi/BigRewrite/myidentify.py:33: UserWarning:
#
# netcdf file tracking_ids are NOT UNIQUE!
# ['hdl:21.14100/b2273e8c-8bdf-432f-bf3b-c5ab1a330848', 'hdl:21.14100/b2273e8c-8bdf-432f-bf3b-c5ab1a330848', 'hdl:21.14100/b2273e8c-8bdf-432f-bf3b-c5ab1a330848', 'hdl:21.14100/b2273e8c-8bdf-432f-bf3b-c5ab1a330848', 'hdl:21.14100/b2273e8c-8bdf-432f-bf3b-c5ab1a330848', 'hdl:21.14100/b2273e8c-8bdf-432f-bf3b-c5ab1a330848', 'hdl:21.14100/b2273e8c-8bdf-432f-bf3b-c5ab1a330848', 'hdl:21.14100/b2273e8c-8bdf-432f-bf3b-c5ab1a330848', 'hdl:21.14100/b2273e8c-8bdf-432f-bf3b-c5ab1a330848']
#
#   warnings.warn("\n" + msg)
# /home/naomi/BigRewrite/myidentify.py:33: UserWarning:
#
# netcdf file tracking_ids are NOT UNIQUE!
# ['hdl:21.14100/2b21e5c7-2c82-4501-8c38-1c6e2cd2361c', 'hdl:21.14100/2b21e5c7-2c82-4501-8c38-1c6e2cd2361c', 'hdl:21.14100/2b21e5c7-2c82-4501-8c38-1c6e2cd2361c', 'hdl:21.14100/2b21e5c7-2c82-4501-8c38-1c6e2cd2361c', 'hdl:21.14100/2b21e5c7-2c82-4501-8c38-1c6e2cd2361c', 'hdl:21.14100/2b21e5c7-2c82-4501-8c38-1c6e2cd2361c', 'hdl:21.14100/2b21e5c7-2c82-4501-8c38-1c6e2cd2361c', 'hdl:21.14100/2b21e5c7-2c82-4501-8c38-1c6e2cd2361c', 'hdl:21.14100/2b21e5c7-2c82-4501-8c38-1c6e2cd2361c']
#
#   warnings.warn("\n" + msg)
# /home/naomi/BigRewrite/myidentify.py:33: UserWarning:
#
# netcdf file tracking_ids are NOT UNIQUE!
# ['hdl:21.14100/176d6bbf-8f86-4f29-ba77-5be058417d76', 'hdl:21.14100/176d6bbf-8f86-4f29-ba77-5be058417d76', 'hdl:21.14100/f8274608-d8b6-484e-8018-08f9868c3da1', 'hdl:21.14100/f8274608-d8b6-484e-8018-08f9868c3da1', 'hdl:21.14100/f8274608-d8b6-484e-8018-08f9868c3da1', 'hdl:21.14100/f8274608-d8b6-484e-8018-08f9868c3da1']
#
#   warnings.warn("\n" + msg)
# /home/naomi/BigRewrite/myidentify.py:33: UserWarning:
#
# netcdf file tracking_ids are NOT UNIQUE!
# ['hdl:21.14100/2d56c491-ea85-4649-ae1c-5b872a99676c', 'hdl:21.14100/2d56c491-ea85-4649-ae1c-5b872a99676c']
#
#   warnings.warn("\n" + msg)
# /home/naomi/BigRewrite/myidentify.py:33: UserWarning:
#
# netcdf file tracking_ids are NOT UNIQUE!
# ['hdl:21.14100/78b27546-b4ee-4e08-b41b-37b99553e609', 'hdl:21.14100/78b27546-b4ee-4e08-b41b-37b99553e609']
#
#   warnings.warn("\n" + msg)
# /home/naomi/BigRewrite/myidentify.py:33: UserWarning:
#
# netcdf file tracking_ids are NOT UNIQUE!
# ['hdl:21.14100/dc9ff8ff-6916-4830-b8b4-e775f885f1d4', 'hdl:21.14100/6e47577f-ea66-436a-903b-e3cbf0ddb3f8', 'hdl:21.14100/6e47577f-ea66-436a-903b-e3cbf0ddb3f8', 'hdl:21.14100/6e47577f-ea66-436a-903b-e3cbf0ddb3f8', 'hdl:21.14100/6e47577f-ea66-436a-903b-e3cbf0ddb3f8']
#
#   warnings.warn("\n" + msg)
# /home/naomi/BigRewrite/myidentify.py:33: UserWarning:
#
# netcdf file tracking_ids are NOT UNIQUE!
# ['hdl:21.14100/8fa4bc16-5329-4a2f-9fda-2b48e5b556c9', 'hdl:21.14100/8fa4bc16-5329-4a2f-9fda-2b48e5b556c9']
#
#   warnings.warn("\n" + msg)
# /home/naomi/BigRewrite/myidentify.py:33: UserWarning:
#
# netcdf file tracking_ids are NOT UNIQUE!
# ['hdl:21.14100/81873a9f-b8aa-4fd5-b7b9-61c30d1d08dc', 'hdl:21.14100/81873a9f-b8aa-4fd5-b7b9-61c30d1d08dc', 'hdl:21.14100/81873a9f-b8aa-4fd5-b7b9-61c30d1d08dc', 'hdl:21.14100/81873a9f-b8aa-4fd5-b7b9-61c30d1d08dc', 'hdl:21.14100/81873a9f-b8aa-4fd5-b7b9-61c30d1d08dc', 'hdl:21.14100/81873a9f-b8aa-4fd5-b7b9-61c30d1d08dc', 'hdl:21.14100/81873a9f-b8aa-4fd5-b7b9-61c30d1d08dc', 'hdl:21.14100/81873a9f-b8aa-4fd5-b7b9-61c30d1d08dc', 'hdl:21.14100/81873a9f-b8aa-4fd5-b7b9-61c30d1d08dc']
#
#   warnings.warn("\n" + msg)
# /home/naomi/BigRewrite/myidentify.py:33: UserWarning:
#
# netcdf file tracking_ids are NOT UNIQUE!
# ['hdl:21.14100/7aaa02f2-0aeb-457d-8147-f4c372ed8b18', 'hdl:21.14100/7aaa02f2-0aeb-457d-8147-f4c372ed8b18']
#
#   warnings.warn("\n" + msg)
# /home/naomi/BigRewrite/myidentify.py:33: UserWarning:
#
# netcdf file tracking_ids are NOT UNIQUE!
# ['hdl:21.14100/aeb1bada-d167-45f8-b065-b50bf974d07a', 'hdl:21.14100/aeb1bada-d167-45f8-b065-b50bf974d07a']
#
#   warnings.warn("\n" + msg)
# /home/naomi/BigRewrite/myidentify.py:33: UserWarning:
#
# netcdf file tracking_ids are NOT UNIQUE!
# ['hdl:21.14100/a1777657-b316-4f9e-9cee-c357f21c9afe', 'hdl:21.14100/a1777657-b316-4f9e-9cee-c357f21c9afe']
#
#   warnings.warn("\n" + msg)
# /home/naomi/BigRewrite/myidentify.py:33: UserWarning:
#
# netcdf file tracking_ids are NOT UNIQUE!
# ['hdl:21.14100/1bb8fbe7-82f0-454d-8e16-0697bde64304', 'hdl:21.14100/1bb8fbe7-82f0-454d-8e16-0697bde64304']
#
#   warnings.warn("\n" + msg)
# /home/naomi/BigRewrite/myidentify.py:33: UserWarning:
#
# netcdf file tracking_ids are NOT UNIQUE!
# ['hdl:21.14100/e6476c75-c12a-46ab-a2d9-39d21559210b', 'hdl:21.14100/e6476c75-c12a-46ab-a2d9-39d21559210b']
#
#   warnings.warn("\n" + msg)

# %%
# A. Make new noQC catalog
#    5. using vstore=zstore+version, update dz_new with status, severity and url columns

# combine zstore and version
dz_new['vstore'] = dz_new.apply(lambda row: row.zstore + 'v' + str(row.version), axis = 1)

# Find vstores (= zstore+version) in dz_GC which have issues at ES-DOC
set_A = set(sorted(list(dz_new.vstore.values))) 
set_B = set(sorted(list(dz_exclude.vstore.values)))

in_both = sorted(list(set_A.intersection(set_B)))
print(len(set_A),len(set_B),len(in_both))

status = []
severity = []
url = []
for index, row in dz_new.iterrows():
    vstore = row.vstore
    if vstore in in_both:
        dze = dz_exclude[dz_exclude.vstore==vstore]
        status += [dze.status.values[0]]
        severity += [dze.severity.values[0]]
        url += [dze.issue_url.values[0]]
    else:
        status += ['good']
        severity += ['none']
        url += ['none']

dz_new['status'] = status
dz_new['severity'] = severity
dz_new['issue_url'] = url
# Out:
# 401937 164212 11485

# %%
# MAKE SURE NEW CATALOG IS LARGER THAN OLD
print(len(dz_new),len(dz_old))
assert len(dz_new) > len(dz_old)
# Out:
# 401937 401452

# %%
# A. Make new noQC catalog
#    6a. save old noQC catalog and then upload to GC

date = str(datetime.datetime.now().strftime("%Y%m%d"))
old_cat = f'old_catalogs/pangeo-cmip6-{date}-noQC.csv'
os.system(f'cp csv/pangeo-cmip6-noQC.csv {old_cat}')
os.system(f'gzip {old_cat}')
ret = os.system(f'/usr/bin/gsutil -m cp {old_cat}.gz gs://cmip6/{old_cat}.gz')

# %%
#    6b. save new noQC catalog and then upload to GC

dz_new.drop(['vstore'],1).to_csv('csv/pangeo-cmip6-noQC.csv', mode='w+', index=False)

ret = os.system('/usr/bin/gsutil -m cp csv/pangeo-cmip6-noQC.csv gs://cmip6/cmip6-zarr-consolidated-stores-noQC.csv')
if ret != 0:
    print('noQC upload not working')

# %% [raw]
# # B. Make new standard catalog
# #    1. eliminate harmless issues from dz_exclude
# #    2. use this (smaller) version to eliminate the more serious issues from standard catalog
# #    3. save new standard catalog and then upload to GC

# %%
# B. Make new standard catalog
#    1. eliminate harmless issues from dz_exclude
#       these should all be properly evaluated - I just made a first guess

dz_exclude = dz_exclude[dz_exclude.status != 'resolved']
dz_exclude = dz_exclude[dz_exclude.severity != 'low']
dz_exclude = dz_exclude[dz_exclude.issue_uid != 'b6302400-3620-c8f1-999b-d192c0349084']
dz_exclude = dz_exclude[dz_exclude.issue_uid != '45f9e7b9-1844-7a92-8b54-10d954e621db']
dz_exclude = dz_exclude[dz_exclude.issue_uid != '4aa40e49-b2d4-0b29-a6b1-c80ee8dce11a']
dz_exclude = dz_exclude[dz_exclude.issue_uid != '2f6b5963-f87e-b2df-a5b0-2f12b6b68d32']
dz_exclude = dz_exclude[dz_exclude.issue_uid != '61fb170e-91bb-4c64-8f1d-6f5e342ee421']
dz_exclude = dz_exclude[dz_exclude.issue_uid != '90cac29b-eaff-c450-8621-ea31e305a40e']
dz_exclude = dz_exclude[dz_exclude.issue_uid != '8fbd8df5-c349-315b-9ec3-5a2f4ec4ec63']
dz_exclude = dz_exclude[dz_exclude.issue_uid != 'ad5ca671-39d0-39ed-bf4f-6c8fb1a06047']

# %%
# B. Make new standard catalog
#    2. use this (smaller) list of issues to eliminate the more serious issues from standard catalog

# Find zstores in both:
set_A = set(sorted(list(dz_new.vstore.values))) 
set_B = set(sorted(list(dz_exclude.vstore.values)))

in_both = sorted(list(set_A.intersection(set_B)))
print(len(set_A),len(set_B),len(in_both))

dfz = dz_new.copy()
dfz['issue'] = [value in in_both for value in dfz.vstore.values]
dz_issues = dfz[dfz.issue]
dz_clean  = dfz[dfz.issue==False]
dz_orig = pd.concat([dfz, dz_issues, dz_issues]).drop_duplicates(keep=False)
dz_orig = dz_orig.drop(['issue','vstore'],1)
# Out:
# 401937 61783 4737

# %%
# MAKE SURE NEW CATALOG IS LARGER THAN OLD
dfcat = pd.read_csv('https://cmip6.storage.googleapis.com/cmip6-zarr-consolidated-stores.csv')
print(len(dz_orig),len(dfcat))
assert len(dz_orig) > len(dfcat)
# Out:
# 397200 396709
# /usr/local/python/anaconda3/envs/pangeo-fall2020/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# B. Make new standard catalog
#    3a. save old standard catalog and then upload to GC

date = str(datetime.datetime.now().strftime("%Y%m%d"))
old_cat = f'old_catalogs/pangeo-cmip6-{date}.csv'
os.system(f'cp csv/pangeo-cmip6.csv {old_cat}')
os.system(f'gzip {old_cat}')
ret = os.system(f'/usr/bin/gsutil -m cp {old_cat}.gz gs://cmip6/{old_cat}.gz')

# %%
# B. Make new standard catalog
#    3b. save new standard catalog and then upload to GC

dz_orig.drop(['status','severity','issue_url'],1).to_csv('csv/pangeo-cmip6.csv', mode='w+', index=False)

ret = os.system('/usr/bin/gsutil -m cp csv/pangeo-cmip6.csv gs://cmip6/cmip6-zarr-consolidated-stores.csv')
if ret != 0:
    print('standard catalog upload not working')
    
ret = os.system('/usr/bin/gsutil -m cp csv/pangeo-cmip6.csv gs://cmip6/pangeo-cmip6.csv')
if ret != 0:
    print('duplicate standard catalog upload not working')

# %%
print(new_drives)
# Out:
# ['/h119/naomi/zarr-minimal', '/net/abbey/a4/naomi/zarr-minimal', '/h122/naomi/zarr-minimal', '/net/carney/d3/naomi/zarr-minimal', '/h121/naomi/zarr-minimal']
