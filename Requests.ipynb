# %% [markdown]
# # To Handle New Data Requests Automatically
# - beginning of notebook is assumed to be interactive until the requests have been checked
# - all progress and exception logging is done only for main loop
# - copy and paste the e-mail response and send from gcs.cmip6.ldeo@gmail.com account

# %%
import pandas as pd
import gcsfs
import xarray as xr
from datetime import datetime
import itertools

# %% [markdown]
# ### Local modules

# %%
import myconfig
from mydataset import id2dict_, dir2url_, dir2dict
from mytasks import Check, Download, ReadFiles, SaveAsZarr, Upload, Cleanup
from mysearch import esgf_search
from myrequest import requests, set_request_id
from myresponse import response, get_details, dict_to_dfcat

# %%
# CONFIGURE ESGF Search here
node_pref = myconfig.node_pref
dtype = myconfig.dtype
myconfig.local_target_prefix = '/h112/naomi/zarr-minimal/'
dir2local = dir2url_(myconfig.local_target_prefix)

ESGF_site = dtype['llnl']
#ESGF_site = dtype['dkrz']

print('zarrs will be written to: ',myconfig.local_target_prefix)
# Out:
# zarrs will be written to:  /h112/naomi/zarr-minimal/

# %%
# CONFIGURE GCS
fs     = gcsfs.GCSFileSystem(token='anon', access='read_only',cache_timeout=-1)
df_GCS = pd.read_csv('https://cmip6.storage.googleapis.com/cmip6-zarr-consolidated-stores-noQC.csv', dtype='unicode')

# make available to all modules
myconfig.fs = fs
myconfig.df_GCS = df_GCS

# %% [markdown]
# ### Get new Google Sheet requests
# - by default, only the new rows from the sheet are considered
# - specifying a list of rows or emails will add older entries

# %%
df_prior = pd.read_csv('csv/requests.csv')

rows = []   
emails = []
rows = [3] #range(0,5) #[0,5,9]
#emails = ['c.wang@princeton.edu']

df_request_new, dtrouble = requests(df_prior,rows=rows,emails=emails)
request_id = set_request_id()

# Check for mal-formed requests (non-existent variables, etc)
if len(dtrouble)>=1:
    print(dtrouble)

# print all active requests:
display(df_request_new)

# by index
#type = 'input'
type = 'last'

if type == 'input':
    resp = input('index?  (after entering number, click on next cell to advance)')
    df_request_new = df_request_new.loc[[int(resp)]]
else:
    timestamps = df_request_new.Timestamp.unique()
    df_request_new = df_request_new[df_request_new.Timestamp == timestamps[0]]

df_request_new
# Out:
#                Timestamp                    E-mail response status members                                        experiments         models                                  variables  table          requester                             science                                           comments
# 3     9/11/2019 18:25:47         nhn2@columbia.edu            once   [All]                                       [historical]          [All]                      [ps, hus, ua, va, ta]   Amon              Naomi                                 NaN                                                NaN
# 209    12/8/2020 4:47:14     hiba.omrani@gmail.com             NaN   [All]       [historical, ssp126, ssp245, ssp370, ssp585]          [All]        [tas, pr, tasmax, tasmin, uas, vas]    day        Hiba Omrani               climat impact studies                                                NaN
# 210  12/11/2020 16:47:24  Hassanakbari22@gmail.com             NaN   [All]                                      [1pctCO2-cdr]  [FGOALS-f3-L]                                      [yes]  CFday      Hassan Akbari                     CMPI6, Research                                                NaN
# 211  12/13/2020 14:07:05  nadiakiran.gis@gmail.com             NaN   [All]  [1pctCO2, abrupt-4xCO2, amip, esm-hist, esm-pi...          [All]  [pr(42717), tasmax(28222), tasmin(28574)]     fx  Syeda Nadia Kiran  impacts of climate change on flood  I want to process CMIP6 data to assess the imp...
#             Timestamp             E-mail response status members   experiments models              variables table requester science comments
# 3  9/11/2019 18:25:47  nhn2@columbia.edu            once   [All]  [historical]  [All]  [ps, hus, ua, va, ta]  Amon     Naomi     NaN      NaN

# %%
all_search = {}
search_keys = {'table':'table_id','experiments':'experiment_id','variables':'variable_id','models':'source_id','members':'member_id'}

for item, row in df_request_new.iterrows():
    all_search['table_id'] = [row.table]
    request = item
    for key in search_keys.keys():
        if key == 'table':
            continue
        klist = row[key]
        if not ('All' in klist)|('One' in klist):  # Note, we no longer get just one member_id without specifying which
            all_search[search_keys[key]] = klist

label = f'request-{request}'

label, all_search
# Out:
# ('request-3',
#  {'table_id': ['Amon'],
#   'experiment_id': ['historical'],
#   'variable_id': ['ps', 'hus', 'ua', 'va', 'ta']})

# %%
update_ESGF = False
if update_ESGF:
    x = [value for key,value in all_search.items()]
    searches = [p for p in itertools.product(*x)]

    dESGF = []
    for s in searches:
        search = dict(zip(all_search.keys(),s))
        print(search)
        df = esgf_search(search, server=ESGF_site)
        if len(df)>0:
            dESGF += [df]

    df_ESGF = pd.concat(dESGF)
    df_ESGF.to_csv(f'csv/ESGF_{label}.csv',index=False)
else:
    df_ESGF = pd.read_csv(f'csv/ESGF_{label}.csv', dtype='unicode')

len(df_ESGF), len(df_ESGF.ds_dir.unique())
# Out:
# (52670, 2705)

# %%
# make df of all needed
NewNeeded = False
if NewNeeded:
    df = pd.merge(df_ESGF,df_GCS, how='outer', indicator=True)
    df_needed = df[df._merge == 'left_only']
    
    keep_keys = df_ESGF.keys()
    all_keys = df.keys()
    drop_keys = list(set(all_keys) - set(keep_keys))
    df_needed = df_needed.drop(drop_keys,1)

    num_stores = 0
    if len(df_needed) > 0:
        num_stores = df_needed.ds_dir.nunique() 
        print(f'needed: nfiles={len(df_needed)}, nstores={num_stores}')
    else:
        print('no new data available')
        exit    
    
    df_needed['member'] = [int(s.split('r')[-1].split('i')[0]) for s in df_needed['member_id']]
    df_needed['zsize'] = [df_needed[df_needed.ds_dir==zs]['file_size'].sum() for zs in df_needed['ds_dir']]
    df_needed = df_needed.sort_values(by=['zsize'])
    
    df_needed.to_csv(f'csv/needed_{label}.csv',index=False)
else:
    df_needed = pd.read_csv(f'csv/needed_{label}.csv')

print('Variables')
for var in df_needed.variable_id.unique():
    print(var,df_needed[df_needed.variable_id==var].ds_dir.nunique())

print('\nExperiments')
for exp in df_needed.experiment_id.unique():
    print(exp,df_needed[df_needed.experiment_id==exp].ds_dir.nunique())
# Out:
# Variables
# ps 2
# va 229
# ta 218
# hus 27
# ua 219
#
# Experiments
# historical 695

# %%
# make available to all modules
myconfig.df_needed = df_needed

# %%
ds_dirs = df_needed.ds_dir.unique()
numdsets = len(ds_dirs)

# %%
progress_log  = f'logs/progress_{label}.log'
failure_log  = f'logs/failure_{label}.log'
success_log  = f'logs/success_{label}.log'
success_log
# Out:
# 'logs/success_request-3.log'

# %%
def write_log(file,str,verbose=True):
    f = open(file,'a')
    if verbose:
        print(str)
    f.write(f'{str}\n')
    f.close()
    return

# %%
# reload the catalog
df_GCS = pd.read_csv('https://cmip6.storage.googleapis.com/cmip6-zarr-consolidated-stores-noQC.csv', dtype='unicode')

# refresh the gcsfs
fs.invalidate_cache()

verbose = False
zdict = {}
for item, ds_dir in enumerate(ds_dirs):
    #if item > 0:
    #    continue
    print(f'\n{item}/{numdsets-1}',ds_dir)

    (ierr, exc) = Check(ds_dir, dir2local)
    if ierr > 0:
        write_log(progress_log,f'{ds_dir} {ierr}: {exc}'); continue
                    
    (gfiles, ierr, exc) = Download(ds_dir)
    if ierr > 0:
        write_log(failure_log,f'{ds_dir},noUse, {ierr}: {exc}'); continue
        
    (ds,ierr,exc) = ReadFiles(ds_dir, gfiles, dir2dict)
    if ierr > 0:
        write_log(failure_log,f'{ds_dir},noUse, {ierr}: {exc}'); continue

    (ierr,exc) = SaveAsZarr(ds_dir, ds, dir2local)
    if ierr > 0:
        write_log(failure_log,f'{ds_dir},noUse, {ierr}: {exc}'); continue
        
    (ierr,exc) = Upload(ds_dir, dir2local)
    if ierr > 0:
        write_log(failure_log,f'{ds_dir},noUse, {ierr}: {exc}'); continue

    (ierr,exc) = Cleanup(ds_dir, gfiles, dir2local)
    if ierr > 0:
        write_log(failure_log,f'{ds_dir},noUse, {ierr}: {exc}'); continue

    vlist = get_details(ds_dir, ds, dir2local)
    zdict[item] = vlist
    
    write_log(success_log,f'{dir2local(ds_dir)} saved to GCS')
# Out:
# 0/694 CMIP/NASA-GISS/GISS-E2-1-G/historical/r7i1p3f1/Amon/ps/gn
# CMIP/NASA-GISS/GISS-E2-1-G/historical/r7i1p3f1/Amon/ps/gn 1: noUse in codes
#
# 1/694 CMIP/EC-Earth-Consortium/EC-Earth3/historical/r3i1p1f1/Amon/ps/gr
# CMIP/EC-Earth-Consortium/EC-Earth3/historical/r3i1p1f1/Amon/ps/gr 1: noUse in codes
#
# 2/694 CMIP/CCCma/CanESM5/historical/r35i1p2f1/Amon/va/gn
# CMIP/CCCma/CanESM5/historical/r35i1p2f1/Amon/va/gn 3: store already in cloud
#
# 3/694 CMIP/CCCma/CanESM5/historical/r33i1p2f1/Amon/va/gn
# CMIP/CCCma/CanESM5/historical/r33i1p2f1/Amon/va/gn 3: store already in cloud
#
# 4/694 CMIP/CCCma/CanESM5/historical/r34i1p2f1/Amon/va/gn
# CMIP/CCCma/CanESM5/historical/r34i1p2f1/Amon/va/gn 3: store already in cloud
#
# 5/694 CMIP/CCCma/CanESM5/historical/r29i1p2f1/Amon/va/gn
# CMIP/CCCma/CanESM5/historical/r29i1p2f1/Amon/va/gn 3: store already in cloud
#
# 6/694 CMIP/CCCma/CanESM5/historical/r37i1p2f1/Amon/va/gn
# CMIP/CCCma/CanESM5/historical/r37i1p2f1/Amon/va/gn 3: store already in cloud
#
# 7/694 CMIP/CCCma/CanESM5/historical/r40i1p2f1/Amon/va/gn
# CMIP/CCCma/CanESM5/historical/r40i1p2f1/Amon/va/gn 3: store already in cloud
1p1f1/Amon/ua/gn
# CMIP/NCC/NorCPM1/historical/r18i1p1f1/Amon/ua/gn 3: store already in cloud
#
# 78/694 CMIP/NCC/NorCPM1/historical/r21i1p1f1/Amon/ua/gn
# CMIP/NCC/NorCPM1/historical/r21i1p1f1/Amon/ua/gn 3: store already in cloud
#
# 79/694 CMIP/NCC/NorCPM1/historical/r17i1p1f1/Amon/ua/gn
# CMIP/NCC/NorCPM1/historical/r17i1p1f1/Amon/ua/gn 3: store already in cloud
#
# 80/694 CMIP/NCC/NorCPM1/historical/r7i1p1f1/Amon/ua/gn
# netcdfs/ua_Amon_NorCPM1_historical_r7i1p1f1_gn_185001-201412.nc
# netcdfs/ua_Amon_NorCPM1_historical_r7i1p1f1_gn_201501-201812.nc
# netcdfs/ua_Amon_NorCPM1_historical_r7i1p1f1_gn_201901-202912.nc
# 179 180
# successfully uploaded to gs://cmip6/CMIP/NCC/NorCPM1/historical/r7i1p1f1/Amon/ua/gn
# /h112/naomi/zarr-minimal/CMIP/NCC/NorCPM1/historical/r7i1p1f1/Amon/ua/gn saved to GCS
#
# 81/694 CMIP/INM/INM-CM5-0/historical/r1i1p1f1/Amon/ta/gr1
# netcdfs/ta_Amon_INM-CM5-0_historical_r1i1p1f1_gr1_185001-185912.nc
# CMIP/INM/INM-CM5-0/historical/r1i1p1f1/Amon/ta/gr1,noUse, 2: Server not responding for: http://esgf-data3.diasjp.net/thredds/fileServer/esg_dataroot/CMIP6/CMIP/INM/INM-CM5-0/historical/r1i1p1f1/Amon/ta/gr1/v20190610/ta_Amon_INM-CM5-0_historical_r1i1p1f1_gr1_185001-185912.nc
#
# 82/694 CMIP/NCC/NorCPM1/historical/r11i1p1f1/Amon/va/gn
# CMIP/NCC/NorCPM1/historical/r11i1p1f1/Amon/va/gn 3: store already in cloud
#
# 83/694 CMIP/NCC/NorCPM1/historical/r12i1p1f1/Amon/va/gn
# CMIP/NCC/NorCPM1/historical/r12i1p1f1/Amon/va/gn 3: store already in cloud
#
# 84/694 CMIP/NCC/NorCPM1/historical/r17i1p1f1/Amon/va/gn
# CMIP/NCC/NorCPM1/historical/r17i1p1f1/Amon/va/gn 3: store already in cloud
#
# 85/694 CMIP/NCC/NorCPM1/historical/r4i1p1f1/Amon/va/gn
# CMIP/NCC/NorCPM1/historical/r4i1p1f1/Amon/va/gn 3: store already in cloud
#
# 86/694 CMIP/NCC/NorCPM1/historical/r22i1p1f1/Amon/va/gn
# CMIP/NCC/NorCPM1/historical/r22i1p1f1/Amon/va/gn 3: store already in cloud
#
# 87/694 CMIP/NCC/NorCPM1/historical/r29i1p1f1/Amon/va/gn
# CMIP/NCC/NorCPM1/historical/r29i1p1f1/Amon/va/gn 3: store already in cloud
#
# 88/694 CMIP/NCC/NorCPM1/historical/r9i1p1f1/Amon/va/gn
# CMIP/NCC/NorCPM1/historical/r9i1p1f1/Amon/va/gn 3: store already in cloud
#
# 89/694 CMIP/NCC/NorCPM1/historical/r24i1p1f1/Amon/va/gn
# CMIP/NCC/NorCPM1/historical/r24i1p1f1/Amon/va/gn 3: store already in cloud
#
# 90/694 CMIP/NCC/NorCPM1/historical/r27i1p1f1/Amon/va/gn
# CMIP/NCC/NorCPM1/historical/r27i1p1f1/Amon/va/gn 3: store already in cloud
#
# 91/694 CMIP/NCC/NorCPM1/historical/r28i1p1f1/Amon/va/gn
# CMIP/NCC/NorCPM1/historical/r28i1p1f1/Amon/va/gn 3: store already in cloud
#
# 92/694 CMIP/NCC/NorCPM1/historical/r21i1p1f1/Amon/va/gn
# CMIP/NCC/NorCPM1/historical/r21i1p1f1/Amon/va/gn 3: store already in cloud
#
# 93/694 CMIP/NCC/NorCPM1/historical/r14i1p1f1/Amon/va/gn
# CMIP/NCC/NorCPM1/historical/r14i1p1f1/Amon/va/gn 3: store already in cloud
#
# 94/694 CMIP/NCC/NorCPM1/historical/r16i1p1f1/Amon/va/gn
# CMIP/NCC/NorCPM1/historical/r16i1p1f1/Amon/va/gn 3: store already in cloud
#
# 95/694 CMIP/NCC/NorCPM1/historical/r15i1p1f1/Amon/va/gn
# CMIP/NCC/NorCPM1/historical/r15i1p1f1/Amon/va/gn 3: store already in cloud
#
# 96/694 CMIP/NCC/NorCPM1/historical/r20i1p1f1/Amon/va/gn
# CMIP/NCC/NorCPM1/historical/r20i1p1f1/Amon/va/gn 3: store already in cloud
#
# 97/694 CMIP/NCC/NorCPM1/historical/r30i1p1f1/Amon/va/gn
# CMIP/NCC/NorCPM1/historical/r30i1p1f1/Amon/va/gn 3: store already in cloud
#
# 98/694 CMIP/NCC/NorCPM1/historical/r13i1p1f1/Amon/va/gn
# CMIP/NCC/NorCPM1/historical/r13i1p1f1/Amon/va/gn 3: store already in cloud
#
# 99/694 CMIP/NCC/NorCPM1/historical/r7i1p1f1/Amon/va/gn
# CMIP/NCC/NorCPM1/historical/r7i1p1f1/Amon/va/gn 3: store already in cloud
#
# 100/694 CMIP/NCC/NorCPM1/historical/r5i1p1f1/Amon/va/gn
# CMIP/NCC/NorCPM1/historical/r5i1p1f1/Amon/va/gn 3: store already in cloud
#
# 101/694 CMIP/NCC/NorCPM1/historical/r2i1p1f1/Amon/va/gn
# CMIP/NCC/NorCPM1/historical/r2i1p1f1/Amon/va/gn 3: store already in cloud
#
# 102/694 CMIP/NCC/NorCPM1/historical/r23i1p1f1/Amon/va/gn
# CMIP/NCC/NorCPM1/historical/r23i1p1f1/Amon/va/gn 3: store already in cloud
#
# 103/694 CMIP/NCC/NorCPM1/historical/r8i1p1f1/Amon/va/gn
# CMIP/NCC/NorCPM1/historical/r8i1p1f1/Amon/va/gn 3: store already in cloud
#
# 104/694 CMIP/NCC/NorCPM1/historical/r25i1p1f1/Amon/va/gn
# CMIP/NCC/NorCPM1/historical/r25i1p1f1/Amon/va/gn 3: store already in cloud
#
# 105/694 CMIP/NCC/NorCPM1/historical/r26i1p1f1/Amon/va/gn
# CMIP/NCC/NorCPM1/historical/r26i1p1f1/Amon/va/gn 3: store already in cloud
#
# 106/694 CMIP/NCC/NorCPM1/historical/r18i1p1f1/Amon/va/gn
# CMIP/NCC/NorCPM1/historical/r18i1p1f1/Amon/va/gn 3: store already in cloud
#
# 107/694 CMIP/NCC/NorCPM1/historical/r6i1p1f1/Amon/va/gn
# CMIP/NCC/NorCPM1/historical/r6i1p1f1/Amon/va/gn 3: store already in cloud
#
# 108/694 CMIP/NCC/NorCPM1/historical/r3i1p1f1/Amon/va/gn
# CMIP/NCC/NorCPM1/historical/r3i1p1f1/Amon/va/gn 3: store already in cloud
#
# 109/694 CMIP/NCC/NorCPM1/historical/r19i1p1f1/Amon/va/gn
# CMIP/NCC/NorCPM1/historical/r19i1p1f1/Amon/va/gn 3: store already in cloud
#
# 110/694 CMIP/NIMS-KMA/UKESM1-0-LL/historical/r13i1p1f2/Amon/ta/gn
# CMIP/NIMS-KMA/UKESM1-0-LL/historical/r13i1p1f2/Amon/ta/gn 3: store already in cloud
#
# 111/694 CMIP/NIMS-KMA/UKESM1-0-LL/historical/r14i1p1f2/Amon/ta/gn
# CMIP/NIMS-KMA/UKESM1-0-LL/historical/r14i1p1f2/Amon/ta/gn 3: store already in cloud
#
# 112/694 CMIP/NASA-GISS/GISS-E2-1-G/historical/r6i1p5f1/Amon/ta/gn
# CMIP/NASA-GISS/GISS-E2-1-G/historical/r6i1p5f1/Amon/ta/gn 3: store already in cloud
#
# 113/694 CMIP/NASA-GISS/GISS-E2-1-G/historical/r2i1p5f1/Amon/ta/gn
# CMIP/NASA-GISS/GISS-E2-1-G/historical/r2i1p5f1/Amon/ta/gn 3: store already in cloud
#
# 114/694 CMIP/NASA-GISS/GISS-E2-1-G/historical/r10i1p3f1/Amon/ta/gn
# CMIP/NASA-GISS/GISS-E2-1-G/historical/r10i1p3f1/Amon/ta/gn 3: store already in cloud
#
# 115/694 CMIP/NASA-GISS/GISS-E2-1-G/historical/r10i1p5f1/Amon/ta/gn
# CMIP/NASA-GISS/GISS-E2-1-G/historical/r10i1p5f1/Amon/ta/gn 3: store already in cloud
#
# 116/694 CMIP/NASA-GISS/GISS-E2-1-G/historical/r4i1p5f1/Amon/ta/gn
# CMIP/NASA-GISS/GISS-E2-1-G/historical/r4i1p5f1/Amon/ta/gn 3: store already in cloud
#
# 117/694 CMIP/NASA-GISS/GISS-E2-1-G/historical/r2i1p3f1/Amon/ta/gn
# CMIP/NASA-GISS/GISS-E2-1-G/historical/r2i1p3f1/Amon/ta/gn 3: store already in cloud
#
# 118/694 CMIP/NASA-GISS/GISS-E2-1-G/historical/r1i1p5f1/Amon/ta/gn
# CMIP/NASA-GISS/GISS-E2-1-G/historical/r1i1p5f1/Amon/ta/gn 3: store already in cloud
#
# 119/694 CMIP/NASA-GISS/GISS-E2-1-G/historical/r9i1p5f1/Amon/ta/gn
# CMIP/NASA-GISS/GISS-E2-1-G/historical/r9i1p5f1/Amon/ta/gn 3: store already in cloud
#
# 120/694 CMIP/NASA-GISS/GISS-E2-1-G/historical/r8i1p5f1/Amon/ta/gn
# CMIP/NASA-GISS/GISS-E2-1-G/historical/r8i1p5f1/Amon/ta/gn 3: store already in cloud
#
# 121/694 CMIP/NASA-GISS/GISS-E2-1-G/historical/r7i1p5f1/Amon/ta/gn
# CMIP/NASA-GISS/GISS-E2-1-G/historical/r7i1p5f1/Amon/ta/gn 3: store already in cloud
#
# 122/694 CMIP/NASA-GISS/GISS-E2-1-G/historical/r3i1p5f1/Amon/ta/gn
# CMIP/NASA-GISS/GISS-E2-1-G/historical/r3i1p5f1/Amon/ta/gn 3: store already in cloud
#
# 123/694 CMIP/NASA-GISS/GISS-E2-1-G/historical/r4i1p3f1/Amon/ta/gn
# CMIP/NASA-GISS/GISS-E2-1-G/historical/r4i1p3f1/Amon/ta/gn 3: store already in cloud
#
# 124/694 CMIP/NASA-GISS/GISS-E2-1-G/historical/r1i1p3f1/Amon/ta/gn
# CMIP/NASA-GISS/GISS-E2-1-G/historical/r1i1p3f1/Amon/ta/gn 3: store already in cloud
#
# 125/694 CMIP/NASA-GISS/GISS-E2-1-G/historical/r1i1p1f3/Amon/ta/gn
# CMIP/NASA-GISS/GISS-E2-1-G/historical/r1i1p1f3/Amon/ta/gn 3: store already in cloud
#
# 126/694 CMIP/NASA-GISS/GISS-E2-1-G/historical/r5i1p1f3/Amon/ta/gn
# CMIP/NASA-GISS/GISS-E2-1-G/historical/r5i1p1f3/Amon/ta/gn 3: store already in cloud
#
# 127/694 CMIP/NASA-GISS/GISS-E2-1-G/historical/r2i1p1f3/Amon/ta/gn
# CMIP/NASA-GISS/GISS-E2-1-G/historical/r2i1p1f3/Amon/ta/gn 3: store already in cloud
#
# 128/694 CMIP/NASA-GISS/GISS-E2-1-G/historical/r4i1p1f3/Amon/ta/gn
# CMIP/NASA-GISS/GISS-E2-1-G/historical/r4i1p1f3/Amon/ta/gn 3: store already in cloud
#
# 129/694 CMIP/NASA-GISS/GISS-E2-1-G/historical/r3i1p3f1/Amon/ta/gn
# CMIP/NASA-GISS/GISS-E2-1-G/historical/r3i1p3f1/Amon/ta/gn 3: store already in cloud
#
# 130/694 CMIP/NASA-GISS/GISS-E2-1-G/historical/r5i1p3f1/Amon/ta/gn
# CMIP/NASA-GISS/GISS-E2-1-G/historical/r5i1p3f1/Amon/ta/gn 3: store already in cloud
#
# 131/694 CMIP/NASA-GISS/GISS-E2-1-G/historical/r3i1p1f3/Amon/ta/gn
# CMIP/NASA-GISS/GISS-E2-1-G/historical/r3i1p1f3/Amon/ta/gn 3: store already in cloud
#
# 132/694 CMIP/NASA-GISS/GISS-E2-1-G/historical/r11i1p1f2/Amon/ta/gn
# CMIP/NASA-GISS/GISS-E2-1-G/historical/r11i1p1f2/Amon/ta/gn 3: store already in cloud
#
# 133/694 CMIP/NASA-GISS/GISS-E2-1-H/historical/r1i1p3f1/Amon/ta/gn
# CMIP/NASA-GISS/GISS-E2-1-H/historical/r1i1p3f1/Amon/ta/gn 3: store already in cloud
#
# 134/694 CMIP/NASA-GISS/GISS-E2-1-H/historical/r2i1p3f1/Amon/ta/gn
# CMIP/NASA-GISS/GISS-E2-1-H/historical/r2i1p3f1/Amon/ta/gn 3: store already in cloud
#
# 135/694 CMIP/NASA-GISS/GISS-E2-1-G/historical/r2i1p3f1/Amon/ua/gn
# CMIP/NASA-GISS/GISS-E2-1-G/historical/r2i1p3f1/Amon/ua/gn 3: store already in cloud
#
# 136/694 CMIP/NASA-GISS/GISS-E2-1-G/historical/r3i1p3f1/Amon/ua/gn
# CMIP/NASA-GISS/GISS-E2-1-G/historical/r3i1p3f1/Amon/ua/gn 3: store already in cloud
#
# 137/694 CMIP/NASA-GISS/GISS-E2-1-G/historical/r1i1p3f1/Amon/ua/gn
# CMIP/NASA-GISS/GISS-E2-1-G/historical/r1i1p3f1/Amon/ua/gn 3: store already in cloud
#
# 138/694 CMIP/NASA-GISS/GISS-E2-1-G/historical/r10i1p3f1/Amon/ua/gn
# CMIP/NASA-GISS/GISS-E2-1-G/historical/r10i1p3f1/Amon/ua/gn 3: store already in cloud
#
# 139/694 CMIP/NASA-GISS/GISS-E2-1-G/historical/r5i1p3f1/Amon/ua/gn
# CMIP/NASA-GISS/GISS-E2-1-G/historical/r5i1p3f1/Amon/ua/gn 3: store already in cloud
#
# 140/694 CMIP/NASA-GISS/GISS-E2-1-G/historical/r4i1p3f1/Amon/ua/gn
# CMIP/NASA-GISS/GISS-E2-1-G/historical/r4i1p3f1/Amon/ua/gn 3: store already in cloud
#
# 141/694 CMIP/NASA-GISS/GISS-E2-1-G/historical/r11i1p1f2/Amon/ua/gn
# CMIP/NASA-GISS/GISS-E2-1-G/historical/r11i1p1f2/Amon/ua/gn 3: store already in cloud
#
# 142/694 CMIP/NASA-GISS/GISS-E2-1-G/historical/r4i1p5f1/Amon/ua/gn
# CMIP/NASA-GISS/GISS-E2-1-G/historical/r4i1p5f1/Amon/ua/gn 3: store already in cloud
#
# 143/694 CMIP/NASA-GISS/GISS-E2-1-G/historical/r9i1p5f1/Amon/ua/gn
# CMIP/NASA-GISS/GISS-E2-1-G/historical/r9i1p5f1/Amon/ua/gn 3: store already in cloud
#
# 144/694 CMIP/NASA-GISS/GISS-E2-1-G/historical/r4i1p1f3/Amon/ua/gn
# CMIP/NASA-GISS/GISS-E2-1-G/historical/r4i1p1f3/Amon/ua/gn 3: store already in cloud
#
# 145/694 CMIP/NASA-GISS/GISS-E2-1-G/historical/r1i1p1f3/Amon/ua/gn
# CMIP/NASA-GISS/GISS-E2-1-G/historical/r1i1p1f3/Amon/ua/gn 3: store already in cloud
#
# 146/694 CMIP/NASA-GISS/GISS-E2-1-G/historical/r5i1p1f3/Amon/ua/gn
# CMIP/NASA-GISS/GISS-E2-1-G/historical/r5i1p1f3/Amon/ua/gn 3: store already in cloud
#
# 147/694 CMIP/NASA-GISS/GISS-E2-1-G/historical/r3i1p1f3/Amon/ua/gn
# CMIP/NASA-GISS/GISS-E2-1-G/historical/r3i1p1f3/Amon/ua/gn 3: store already in cloud
#
# 148/694 CMIP/NASA-GISS/GISS-E2-1-G/historical/r2i1p1f3/Amon/ua/gn
# CMIP/NASA-GISS/GISS-E2-1-G/historical/r2i1p1f3/Amon/ua/gn 3: store already in cloud
#
# 149/694 CMIP/NASA-GISS/GISS-E2-1-G/historical/r2i1p5f1/Amon/ua/gn
# CMIP/NASA-GISS/GISS-E2-1-G/historical/r2i1p5f1/Amon/ua/gn 3: store already in cloud
#
# 150/694 CMIP/NASA-GISS/GISS-E2-1-G/historical/r3i1p5f1/Amon/ua/gn
# CMIP/NASA-GISS/GISS-E2-1-G/historical/r3i1p5f1/Amon/ua/gn 3: store already in cloud
#
# 151/694 CMIP/NASA-GISS/GISS-E2-1-G/historical/r8i1p5f1/Amon/ua/gn
# CMIP/NASA-GISS/GISS-E2-1-G/historical/r8i1p5f1/Amon/ua/gn 3: store already in cloud
#
# 152/694 CMIP/NASA-GISS/GISS-E2-1-G/historical/r7i1p5f1/Amon/ua/gn
# CMIP/NASA-GISS/GISS-E2-1-G/historical/r7i1p5f1/Amon/ua/gn 3: store already in cloud
#
# 153/694 CMIP/NASA-GISS/GISS-E2-1-G/historical/r10i1p5f1/Amon/ua/gn
# CMIP/NASA-GISS/GISS-E2-1-G/historical/r10i1p5f1/Amon/ua/gn 3: store already in cloud
#
# 154/694 CMIP/NASA-GISS/GISS-E2-1-G/historical/r6i1p5f1/Amon/ua/gn
# CMIP/NASA-GISS/GISS-E2-1-G/historical/r6i1p5f1/Amon/ua/gn 3: store already in cloud
#
# 155/694 CMIP/NASA-GISS/GISS-E2-1-G/historical/r1i1p5f1/Amon/ua/gn
# CMIP/NASA-GISS/GISS-E2-1-G/historical/r1i1p5f1/Amon/ua/gn 3: store already in cloud
#
# 156/694 CMIP/NASA-GISS/GISS-E2-1-G/historical/r8i1p5f1/Amon/va/gn
# CMIP/NASA-GISS/GISS-E2-1-G/historical/r8i1p5f1/Amon/va/gn 3: store already in cloud
#
# 157/694 CMIP/NASA-GISS/GISS-E2-1-G/historical/r10i1p5f1/Amon/va/gn
# CMIP/NASA-GISS/GISS-E2-1-G/historical/r10i1p5f1/Amon/va/gn 3: store already in cloud
#
# 158/694 CMIP/NASA-GISS/GISS-E2-1-G/historical/r11i1p1f2/Amon/va/gn
# CMIP/NASA-GISS/GISS-E2-1-G/historical/r11i1p1f2/Amon/va/gn 3: store already in cloud
#
# 159/694 CMIP/NASA-GISS/GISS-E2-1-G/historical/r2i1p1f3/Amon/va/gn
# CMIP/NASA-GISS/GISS-E2-1-G/historical/r2i1p1f3/Amon/va/gn 3: store already in cloud
#
# 160/694 CMIP/NASA-GISS/GISS-E2-1-G/historical/r3i1p1f3/Amon/va/gn
# CMIP/NASA-GISS/GISS-E2-1-G/historical/r3i1p1f3/Amon/va/gn 3: store already in cloud
#
# 161/694 CMIP/NASA-GISS/GISS-E2-1-G/historical/r1i1p1f3/Amon/va/gn
# CMIP/NASA-GISS/GISS-E2-1-G/historical/r1i1p1f3/Amon/va/gn 3: store already in cloud
#
# 162/694 CMIP/NASA-GISS/GISS-E2-1-G/historical/r4i1p1f3/Amon/va/gn
# CMIP/NASA-GISS/GISS-E2-1-G/historical/r4i1p1f3/Amon/va/gn 3: store already in cloud
#
# 163/694 CMIP/NASA-GISS/GISS-E2-1-G/historical/r6i1p5f1/Amon/va/gn
# CMIP/NASA-GISS/GISS-E2-1-G/historical/r6i1p5f1/Amon/va/gn 3: store already in cloud
#
# 164/694 CMIP/NASA-GISS/GISS-E2-1-G/historical/r5i1p1f3/Amon/va/gn
# CMIP/NASA-GISS/GISS-E2-1-G/historical/r5i1p1f3/Amon/va/gn 3: store already in cloud
#
# 165/694 CMIP/NASA-GISS/GISS-E2-1-G/historical/r1i1p3f1/Amon/va/gn
# CMIP/NASA-GISS/GISS-E2-1-G/historical/r1i1p3f1/Amon/va/gn 3: store already in cloud
#
# 166/694 CMIP/NASA-GISS/GISS-E2-1-G/historical/r10i1p3f1/Amon/va/gn
# CMIP/NASA-GISS/GISS-E2-1-G/historical/r10i1p3f1/Amon/va/gn 3: store already in cloud
#
# 167/694 CMIP/NASA-GISS/GISS-E2-1-G/historical/r5i1p3f1/Amon/va/gn
# CMIP/NASA-GISS/GISS-E2-1-G/historical/r5i1p3f1/Amon/va/gn 3: store already in cloud
#
# 168/694 CMIP/NASA-GISS/GISS-E2-1-G/historical/r3i1p3f1/Amon/va/gn
# CMIP/NASA-GISS/GISS-E2-1-G/historical/r3i1p3f1/Amon/va/gn 3: store already in cloud
#
# 169/694 CMIP/NASA-GISS/GISS-E2-1-G/historical/r4i1p3f1/Amon/va/gn
# CMIP/NASA-GISS/GISS-E2-1-G/historical/r4i1p3f1/Amon/va/gn 3: store already in cloud
#
# 170/694 CMIP/NASA-GISS/GISS-E2-1-G/historical/r2i1p3f1/Amon/va/gn
# CMIP/NASA-GISS/GISS-E2-1-G/historical/r2i1p3f1/Amon/va/gn 3: store already in cloud
#
# 171/694 CMIP/NASA-GISS/GISS-E2-1-G/historical/r3i1p5f1/Amon/va/gn
# CMIP/NASA-GISS/GISS-E2-1-G/historical/r3i1p5f1/Amon/va/gn 3: store already in cloud
#
# 172/694 CMIP/NASA-GISS/GISS-E2-1-G/historical/r2i1p5f1/Amon/va/gn
# CMIP/NASA-GISS/GISS-E2-1-G/historical/r2i1p5f1/Amon/va/gn 3: store already in cloud
#
# 173/694 CMIP/NASA-GISS/GISS-E2-1-G/historical/r1i1p5f1/Amon/va/gn
# CMIP/NASA-GISS/GISS-E2-1-G/historical/r1i1p5f1/Amon/va/gn 3: store already in cloud
#
# 174/694 CMIP/NASA-GISS/GISS-E2-1-G/historical/r7i1p5f1/Amon/va/gn
# CMIP/NASA-GISS/GISS-E2-1-G/historical/r7i1p5f1/Amon/va/gn 3: store already in cloud
#
# 175/694 CMIP/NASA-GISS/GISS-E2-1-G/historical/r9i1p5f1/Amon/va/gn
# CMIP/NASA-GISS/GISS-E2-1-G/historical/r9i1p5f1/Amon/va/gn 3: store already in cloud
#
# 176/694 CMIP/NASA-GISS/GISS-E2-1-G/historical/r4i1p5f1/Amon/va/gn
# CMIP/NASA-GISS/GISS-E2-1-G/historical/r4i1p5f1/Amon/va/gn 3: store already in cloud
#
# 177/694 CMIP/NASA-GISS/GISS-E2-1-H/historical/r2i1p3f1/Amon/ua/gn
# CMIP/NASA-GISS/GISS-E2-1-H/historical/r2i1p3f1/Amon/ua/gn 3: store already in cloud
#
# 178/694 CMIP/NASA-GISS/GISS-E2-1-H/historical/r1i1p3f1/Amon/ua/gn
# CMIP/NASA-GISS/GISS-E2-1-H/historical/r1i1p3f1/Amon/ua/gn 3: store already in cloud
#
# 179/694 CMIP/NASA-GISS/GISS-E2-1-H/historical/r1i1p3f1/Amon/va/gn
# CMIP/NASA-GISS/GISS-E2-1-H/historical/r1i1p3f1/Amon/va/gn 3: store already in cloud
#
# 180/694 CMIP/NASA-GISS/GISS-E2-1-H/historical/r2i1p3f1/Amon/va/gn
# CMIP/NASA-GISS/GISS-E2-1-H/historical/r2i1p3f1/Amon/va/gn 3: store already in cloud
#
# 181/694 CMIP/MOHC/UKESM1-0-LL/historical/r12i1p1f2/Amon/ua/gn
# CMIP/MOHC/UKESM1-0-LL/historical/r12i1p1f2/Amon/ua/gn 3: store already in cloud
#
# 182/694 CMIP/NIMS-KMA/UKESM1-0-LL/historical/r13i1p1f2/Amon/ua/gn
# CMIP/NIMS-KMA/UKESM1-0-LL/historical/r13i1p1f2/Amon/ua/gn 3: store already in cloud
#
# 183/694 CMIP/MOHC/UKESM1-0-LL/historical/r11i1p1f2/Amon/ua/gn
# CMIP/MOHC/UKESM1-0-LL/historical/r11i1p1f2/Amon/ua/gn 3: store already in cloud
#
# 184/694 CMIP/MOHC/UKESM1-0-LL/historical/r16i1p1f2/Amon/ua/gn
# CMIP/MOHC/UKESM1-0-LL/historical/r16i1p1f2/Amon/ua/gn 3: store already in cloud
#
# 185/694 CMIP/NIMS-KMA/UKESM1-0-LL/historical/r14i1p1f2/Amon/ua/gn
# CMIP/NIMS-KMA/UKESM1-0-LL/historical/r14i1p1f2/Amon/ua/gn 3: store already in cloud
#
# 186/694 CMIP/CCCR-IITM/IITM-ESM/historical/r1i1p1f1/Amon/ta/gn
# netcdfs/ta_Amon_IITM-ESM_historical_r1i1p1f1_gn_185001-185912.nc
# CMIP/CCCR-IITM/IITM-ESM/historical/r1i1p1f1/Amon/ta/gn,noUse, 2: Server not responding for: http://esgf-data3.diasjp.net/thredds/fileServer/esg_dataroot/CMIP6/CMIP/CCCR-IITM/IITM-ESM/historical/r1i1p1f1/Amon/ta/gn/v20191226/ta_Amon_IITM-ESM_historical_r1i1p1f1_gn_185001-185912.nc
#
# 187/694 CMIP/MOHC/UKESM1-0-LL/historical/r12i1p1f2/Amon/va/gn
# CMIP/MOHC/UKESM1-0-LL/historical/r12i1p1f2/Amon/va/gn 3: store already in cloud
#
# 188/694 CMIP/NIMS-KMA/UKESM1-0-LL/historical/r13i1p1f2/Amon/va/gn
# CMIP/NIMS-KMA/UKESM1-0-LL/historical/r13i1p1f2/Amon/va/gn 3: store already in cloud
#
# 189/694 CMIP/MOHC/UKESM1-0-LL/historical/r16i1p1f2/Amon/va/gn
# CMIP/MOHC/UKESM1-0-LL/historical/r16i1p1f2/Amon/va/gn 3: store already in cloud
#
# 190/694 CMIP/NIMS-KMA/UKESM1-0-LL/historical/r14i1p1f2/Amon/va/gn
# CMIP/NIMS-KMA/UKESM1-0-LL/historical/r14i1p1f2/Amon/va/gn 3: store already in cloud
#
# 191/694 CMIP/MOHC/UKESM1-0-LL/historical/r11i1p1f2/Amon/va/gn
# CMIP/MOHC/UKESM1-0-LL/historical/r11i1p1f2/Amon/va/gn 3: store already in cloud
#
# 192/694 CMIP/CAS/FGOALS-g3/historical/r4i1p1f1/Amon/ta/gn
# CMIP/CAS/FGOALS-g3/historical/r4i1p1f1/Amon/ta/gn 3: store already in cloud
#
# 193/694 CMIP/CAS/FGOALS-g3/historical/r4i1p1f1/Amon/ua/gn
# CMIP/CAS/FGOALS-g3/historical/r4i1p1f1/Amon/ua/gn 3: store already in cloud
#
# 194/694 CMIP/CAS/FGOALS-g3/historical/r4i1p1f1/Amon/va/gn
# CMIP/CAS/FGOALS-g3/historical/r4i1p1f1/Amon/va/gn 3: store already in cloud
#
# 195/694 CMIP/CAS/FGOALS-g3/historical/r5i1p1f1/Amon/ta/gn
# CMIP/CAS/FGOALS-g3/historical/r5i1p1f1/Amon/ta/gn 3: store already in cloud
#
# 196/694 CMIP/CAS/FGOALS-g3/historical/r6i1p1f1/Amon/ta/gn
# CMIP/CAS/FGOALS-g3/historical/r6i1p1f1/Amon/ta/gn 3: store already in cloud
#
# 197/694 CMIP/CAS/FGOALS-g3/historical/r5i1p1f1/Amon/ua/gn
# CMIP/CAS/FGOALS-g3/historical/r5i1p1f1/Amon/ua/gn 3: store already in cloud
#
# 198/694 CMIP/CAS/FGOALS-g3/historical/r6i1p1f1/Amon/ua/gn
# CMIP/CAS/FGOALS-g3/historical/r6i1p1f1/Amon/ua/gn 3: store already in cloud
#
# 199/694 CMIP/CAS/FGOALS-g3/historical/r6i1p1f1/Amon/va/gn
# CMIP/CAS/FGOALS-g3/historical/r6i1p1f1/Amon/va/gn 3: store already in cloud
#
# 200/694 CMIP/CAS/FGOALS-g3/historical/r5i1p1f1/Amon/va/gn
# CMIP/CAS/FGOALS-g3/historical/r5i1p1f1/Amon/va/gn 3: store already in cloud
#
# 201/694 CMIP/CAS/FGOALS-g3/historical/r4i1p1f1/Amon/hus/gn
# CMIP/CAS/FGOALS-g3/historical/r4i1p1f1/Amon/hus/gn 3: store already in cloud
#
# 202/694 CMIP/CAS/FGOALS-g3/historical/r6i1p1f1/Amon/hus/gn
# CMIP/CAS/FGOALS-g3/historical/r6i1p1f1/Amon/hus/gn 3: store already in cloud
#
# 203/694 CMIP/CAS/FGOALS-g3/historical/r5i1p1f1/Amon/hus/gn
# CMIP/CAS/FGOALS-g3/historical/r5i1p1f1/Amon/hus/gn 3: store already in cloud
#
# 204/694 CMIP/INM/INM-CM5-0/historical/r1i1p1f1/Amon/ua/gr1
# netcdfs/ua_Amon_INM-CM5-0_historical_r1i1p1f1_gr1_185001-185912.nc
# netcdfs/ua_Amon_INM-CM5-0_historical_r1i1p1f1_gr1_186001-186912.nc
# netcdfs/ua_Amon_INM-CM5-0_historical_r1i1p1f1_gr1_187001-187912.nc
# netcdfs/ua_Amon_INM-CM5-0_historical_r1i1p1f1_gr1_188001-188912.nc
# CMIP/INM/INM-CM5-0/historical/r1i1p1f1/Amon/ua/gr1,noUse, 2: Server not responding for: http://esgf-data3.diasjp.net/thredds/fileServer/esg_dataroot/CMIP6/CMIP/INM/INM-CM5-0/historical/r1i1p1f1/Amon/ua/gr1/v20190610/ua_Amon_INM-CM5-0_historical_r1i1p1f1_gr1_188001-188912.nc
#
# 205/694 CMIP/INM/INM-CM5-0/historical/r2i1p1f1/Amon/ta/gr1
# netcdfs/ta_Amon_INM-CM5-0_historical_r2i1p1f1_gr1_185001-185912.nc
# CMIP/INM/INM-CM5-0/historical/r2i1p1f1/Amon/ta/gr1,noUse, 2: Server not responding for: http://esgf-data3.diasjp.net/thredds/fileServer/esg_dataroot/CMIP6/CMIP/INM/INM-CM5-0/historical/r2i1p1f1/Amon/ta/gr1/v20190704/ta_Amon_INM-CM5-0_historical_r2i1p1f1_gr1_185001-185912.nc
#
# 206/694 CMIP/MIROC/MIROC6/historical/r33i1p1f1/Amon/ta/gn
# CMIP/MIROC/MIROC6/historical/r33i1p1f1/Amon/ta/gn 3: store already in cloud
#
# 207/694 CMIP/MIROC/MIROC6/historical/r47i1p1f1/Amon/ta/gn
# CMIP/MIROC/MIROC6/historical/r47i1p1f1/Amon/ta/gn 3: store already in cloud
#
# 208/694 CMIP/MIROC/MIROC6/historical/r17i1p1f1/Amon/ta/gn
# CMIP/MIROC/MIROC6/historical/r17i1p1f1/Amon/ta/gn 3: store already in cloud
#
# 209/694 CMIP/MIROC/MIROC6/historical/r12i1p1f1/Amon/ta/gn
# CMIP/MIROC/MIROC6/historical/r12i1p1f1/Amon/ta/gn 3: store already in cloud
#
# 210/694 CMIP/MIROC/MIROC6/historical/r35i1p1f1/Amon/ta/gn
# CMIP/MIROC/MIROC6/historical/r35i1p1f1/Amon/ta/gn 3: store already in cloud
#
# 211/694 CMIP/MIROC/MIROC6/historical/r40i1p1f1/Amon/ta/gn
# CMIP/MIROC/MIROC6/historical/r40i1p1f1/Amon/ta/gn 3: store already in cloud
#
# 212/694 CMIP/MIROC/MIROC6/historical/r41i1p1f1/Amon/ta/gn
# CMIP/MIROC/MIROC6/historical/r41i1p1f1/Amon/ta/gn 3: store already in cloud
#
# 213/694 CMIP/MIROC/MIROC6/historical/r24i1p1f1/Amon/ta/gn
# CMIP/MIROC/MIROC6/historical/r24i1p1f1/Amon/ta/gn 3: store already in cloud
#
# 214/694 CMIP/MIROC/MIROC6/historical/r27i1p1f1/Amon/ta/gn
# CMIP/MIROC/MIROC6/historical/r27i1p1f1/Amon/ta/gn 3: store already in cloud
#
# 215/694 CMIP/MIROC/MIROC6/historical/r31i1p1f1/Amon/ta/gn
# CMIP/MIROC/MIROC6/historical/r31i1p1f1/Amon/ta/gn 3: store already in cloud
#
# 216/694 CMIP/MIROC/MIROC6/historical/r25i1p1f1/Amon/ta/gn
# CMIP/MIROC/MIROC6/historical/r25i1p1f1/Amon/ta/gn 3: store already in cloud
#
# 217/694 CMIP/MIROC/MIROC6/historical/r36i1p1f1/Amon/ta/gn
# CMIP/MIROC/MIROC6/historical/r36i1p1f1/Amon/ta/gn 3: store already in cloud
#
# 218/694 CMIP/MIROC/MIROC6/historical/r50i1p1f1/Amon/ta/gn
# CMIP/MIROC/MIROC6/historical/r50i1p1f1/Amon/ta/gn 3: store already in cloud
#
# 219/694 CMIP/MIROC/MIROC6/historical/r15i1p1f1/Amon/ta/gn
# CMIP/MIROC/MIROC6/historical/r15i1p1f1/Amon/ta/gn 3: store already in cloud
#
# 220/694 CMIP/MIROC/MIROC6/historical/r32i1p1f1/Amon/ta/gn
# CMIP/MIROC/MIROC6/historical/
1p1f1/Amon/ta/gn 3: store already in cloud
#
# 250/694 CMIP/CSIRO-ARCCSS/ACCESS-CM2/historical/r3i1p1f1/Amon/ua/gn
# CMIP/CSIRO-ARCCSS/ACCESS-CM2/historical/r3i1p1f1/Amon/ua/gn 3: store already in cloud
#
# 251/694 CMIP/CSIRO-ARCCSS/ACCESS-CM2/historical/r3i1p1f1/Amon/va/gn
# CMIP/CSIRO-ARCCSS/ACCESS-CM2/historical/r3i1p1f1/Amon/va/gn 3: store already in cloud
#
# 252/694 CMIP/KIOST/KIOST-ESM/historical/r1i1p1f1/Amon/ta/gr1
# CMIP/KIOST/KIOST-ESM/historical/r1i1p1f1/Amon/ta/gr1 3: store already in cloud
#
# 253/694 CMIP/KIOST/KIOST-ESM/historical/r1i1p1f1/Amon/ua/gr1
# CMIP/KIOST/KIOST-ESM/historical/r1i1p1f1/Amon/ua/gr1 3: store already in cloud
#
# 254/694 CMIP/KIOST/KIOST-ESM/historical/r1i1p1f1/Amon/va/gr1
# CMIP/KIOST/KIOST-ESM/historical/r1i1p1f1/Amon/va/gr1 3: store already in cloud
#
# 255/694 CMIP/INM/INM-CM5-0/historical/r2i1p1f1/Amon/ua/gr1
# CMIP/INM/INM-CM5-0/historical/r2i1p1f1/Amon/ua/gr1 3: store already in cloud
#
# 256/694 CMIP/INM/INM-CM5-0/historical/r2i1p1f1/Amon/va/gr1
# netcdfs/va_Amon_INM-CM5-0_historical_r2i1p1f1_gr1_185001-185912.nc
# netcdfs/va_Amon_INM-CM5-0_historical_r2i1p1f1_gr1_186001-186912.nc
# netcdfs/va_Amon_INM-CM5-0_historical_r2i1p1f1_gr1_187001-187912.nc
# netcdfs/va_Amon_INM-CM5-0_historical_r2i1p1f1_gr1_188001-188912.nc
# netcdfs/va_Amon_INM-CM5-0_historical_r2i1p1f1_gr1_189001-189912.nc
# CMIP/INM/INM-CM5-0/historical/r2i1p1f1/Amon/va/gr1,noUse, 3: netcdf download not complete
#
# 257/694 CMIP/CSIRO/ACCESS-ESM1-5/historical/r8i1p1f1/Amon/ta/gn
# CMIP/CSIRO/ACCESS-ESM1-5/historical/r8i1p1f1/Amon/ta/gn 3: store already in cloud
#
# 258/694 CMIP/CSIRO/ACCESS-ESM1-5/historical/r7i1p1f1/Amon/ta/gn
# CMIP/CSIRO/ACCESS-ESM1-5/historical/r7i1p1f1/Amon/ta/gn 3: store already in cloud
#
# 259/694 CMIP/CSIRO/ACCESS-ESM1-5/historical/r18i1p1f1/Amon/ta/gn
# CMIP/CSIRO/ACCESS-ESM1-5/historical/r18i1p1f1/Amon/ta/gn 3: store already in cloud
#
# 260/694 CMIP/CSIRO/ACCESS-ESM1-5/historical/r5i1p1f1/Amon/ta/gn
# CMIP/CSIRO/ACCESS-ESM1-5/historical/r5i1p1f1/Amon/ta/gn 3: store already in cloud
#
# 261/694 CMIP/CSIRO/ACCESS-ESM1-5/historical/r13i1p1f1/Amon/ta/gn
# CMIP/CSIRO/ACCESS-ESM1-5/historical/r13i1p1f1/Amon/ta/gn 3: store already in cloud
#
# 262/694 CMIP/CSIRO/ACCESS-ESM1-5/historical/r14i1p1f1/Amon/ta/gn
# CMIP/CSIRO/ACCESS-ESM1-5/historical/r14i1p1f1/Amon/ta/gn 3: store already in cloud
#
# 263/694 CMIP/CSIRO/ACCESS-ESM1-5/historical/r15i1p1f1/Amon/ta/gn
# CMIP/CSIRO/ACCESS-ESM1-5/historical/r15i1p1f1/Amon/ta/gn 3: store already in cloud
#
# 264/694 CMIP/CSIRO/ACCESS-ESM1-5/historical/r6i1p1f1/Amon/ta/gn
# CMIP/CSIRO/ACCESS-ESM1-5/historical/r6i1p1f1/Amon/ta/gn 3: store already in cloud
#
# 265/694 CMIP/CSIRO/ACCESS-ESM1-5/historical/r16i1p1f1/Amon/ta/gn
# CMIP/CSIRO/ACCESS-ESM1-5/historical/r16i1p1f1/Amon/ta/gn 3: store already in cloud
#
# 266/694 CMIP/CSIRO/ACCESS-ESM1-5/historical/r11i1p1f1/Amon/ta/gn
# CMIP/CSIRO/ACCESS-ESM1-5/historical/r11i1p1f1/Amon/ta/gn 3: store already in cloud
#
# 267/694 CMIP/CSIRO/ACCESS-ESM1-5/historical/r3i1p1f1/Amon/ta/gn
# CMIP/CSIRO/ACCESS-ESM1-5/historical/r3i1p1f1/Amon/ta/gn 3: store already in cloud
#
# 268/694 CMIP/CSIRO/ACCESS-ESM1-5/historical/r20i1p1f1/Amon/ta/gn
# CMIP/CSIRO/ACCESS-ESM1-5/historical/r20i1p1f1/Amon/ta/gn 3: store already in cloud
#
# 269/694 CMIP/CSIRO/ACCESS-ESM1-5/historical/r19i1p1f1/Amon/ta/gn
# CMIP/CSIRO/ACCESS-ESM1-5/historical/r19i1p1f1/Amon/ta/gn 3: store already in cloud
#
# 270/694 CMIP/CSIRO/ACCESS-ESM1-5/historical/r12i1p1f1/Amon/ta/gn
# CMIP/CSIRO/ACCESS-ESM1-5/historical/r12i1p1f1/Amon/ta/gn 3: store already in cloud
#
# 271/694 CMIP/CSIRO/ACCESS-ESM1-5/historical/r17i1p1f1/Amon/ta/gn
# CMIP/CSIRO/ACCESS-ESM1-5/historical/r17i1p1f1/Amon/ta/gn 3: store already in cloud
#
# 272/694 CMIP/CSIRO/ACCESS-ESM1-5/historical/r4i1p1f1/Amon/ta/gn
# CMIP/CSIRO/ACCESS-ESM1-5/historical/r4i1p1f1/Amon/ta/gn 3: store already in cloud
#
# 273/694 CMIP/CSIRO/ACCESS-ESM1-5/historical/r10i1p1f1/Amon/ta/gn
# CMIP/CSIRO/ACCESS-ESM1-5/historical/r10i1p1f1/Amon/ta/gn 3: store already in cloud
#
# 274/694 CMIP/CSIRO/ACCESS-ESM1-5/historical/r9i1p1f1/Amon/ta/gn
# CMIP/CSIRO/ACCESS-ESM1-5/historical/r9i1p1f1/Amon/ta/gn 3: store already in cloud
#
# 275/694 CMIP/CSIRO/ACCESS-ESM1-5/historical/r13i1p1f1/Amon/hus/gn
# CMIP/CSIRO/ACCESS-ESM1-5/historical/r13i1p1f1/Amon/hus/gn 3: store already in cloud
#
# 276/694 CMIP/CSIRO/ACCESS-ESM1-5/historical/r12i1p1f1/Amon/hus/gn
# CMIP/CSIRO/ACCESS-ESM1-5/historical/r12i1p1f1/Amon/hus/gn 3: store already in cloud
#
# 277/694 CMIP/CSIRO/ACCESS-ESM1-5/historical/r16i1p1f1/Amon/hus/gn
# CMIP/CSIRO/ACCESS-ESM1-5/historical/r16i1p1f1/Amon/hus/gn 3: store already in cloud
#
# 278/694 CMIP/CSIRO/ACCESS-ESM1-5/historical/r18i1p1f1/Amon/hus/gn
# CMIP/CSIRO/ACCESS-ESM1-5/historical/r18i1p1f1/Amon/hus/gn 3: store already in cloud
#
# 279/694 CMIP/CSIRO/ACCESS-ESM1-5/historical/r15i1p1f1/Amon/hus/gn
# CMIP/CSIRO/ACCESS-ESM1-5/historical/r15i1p1f1/Amon/hus/gn 3: store already in cloud
#
# 280/694 CMIP/CSIRO/ACCESS-ESM1-5/historical/r11i1p1f1/Amon/hus/gn
# CMIP/CSIRO/ACCESS-ESM1-5/historical/r11i1p1f1/Amon/hus/gn 3: store already in cloud
#
# 281/694 CMIP/CSIRO/ACCESS-ESM1-5/historical/r20i1p1f1/Amon/hus/gn
# CMIP/CSIRO/ACCESS-ESM1-5/historical/r20i1p1f1/Amon/hus/gn 3: store already in cloud
#
# 282/694 CMIP/CSIRO/ACCESS-ESM1-5/historical/r17i1p1f1/Amon/hus/gn
# CMIP/CSIRO/ACCESS-ESM1-5/historical/r17i1p1f1/Amon/hus/gn 3: store already in cloud
#
# 283/694 CMIP/CSIRO/ACCESS-ESM1-5/historical/r14i1p1f1/Amon/hus/gn
# netcdfs/hus_Amon_ACCESS-ESM1-5_historical_r14i1p1f1_gn_185001-194912.nc
# netcdfs/hus_Amon_ACCESS-ESM1-5_historical_r14i1p1f1_gn_195001-201412.nc
# 164 165
# successfully uploaded to gs://cmip6/CMIP/CSIRO/ACCESS-ESM1-5/historical/r14i1p1f1/Amon/hus/gn
# /h112/naomi/zarr-minimal/CMIP/CSIRO/ACCESS-ESM1-5/historical/r14i1p1f1/Amon/hus/gn saved to GCS
#
# 284/694 CMIP/CSIRO/ACCESS-ESM1-5/historical/r19i1p1f1/Amon/hus/gn
# netcdfs/hus_Amon_ACCESS-ESM1-5_historical_r19i1p1f1_gn_185001-194912.nc

# %%
assert False

# %% [markdown]
# ### Make a table of acquired data to send in email to requestor

# %%
if len(zdict) == 0 :
    print('nothing else to do')
    exit
else:
    dz = dict_to_dfcat(zdict)

# %%
dz.zstore.values

# %%
try:
    df_master_new = pd.concat([df_GCS, dz],sort=True)
except:
    df_master_new = df_GCS

# %%
ldict = []
names = ""
print('Re: CMIP6 GCS Data Request (Responses)')
for row in df_request_new.values:
    rdict = dict(zip(df_request_new.keys(),row))
    #print(rdict)
    name = rdict['requester']
    timestamp = rdict['Timestamp']
    names += name
    del rdict['response status']
    ldict += [rdict]
    dfr = df_request_new[df_request_new.Timestamp == timestamp]
    
    print('Dear',name+':')
    print('\n  Here are the results from your recent CMIP6 data request(s).  The master catalog, https://cmip6.storage.googleapis.com/cmip6-zarr-consolidated-stores.csv, will be updated with the nightly build.')
    #if len(dtrouble)>=1:
    #    print('\n '+dtrouble)
    print('\n  Please note: ')
    print('      - Data for some models (e.g., CAS/FGOALS-f3-L and NUIST/NESM3) must be obtained directly from servers which are too slow or unresponsive. ')
    print('      - We exclude data with known errors (as reported at ES-DOC) from the official listing at https://errata.es-doc.org/ .')
    print('        However, data labelled status=resolved or severity=low are included in the master catalog.')
    

    print('      - Some data we have not been able to clean up enough to get it concatenated and save to zarr. Other datasets are only available for disjointed time periods.')
    print('\n  See the sample Jupyter Notebook at https://gist.github.com/naomi-henderson/ed1801d8ee8b992dda252f8b126876a5 for a quick introduction to accessing the data.')
    print('\nFrom the folks at:\n  The Climate Data Science Lab\n  Division of Ocean and Climate Physics\n  LDEO/Columbia University')
    print('\n--------------------------')

    print('\nrequest:')
    display(rdict)

    print('\nresponse:')
    try:
        print('new stores added:\n',len(dz),'\n')
    except:
        print(f'no new data available at ESGF API search node {ESGF_site}')

    #print('\n',dfr,len(df_master_new))
    table = response(dfr,df_master_new)

    print("\navailable data:\n  this includes your new stores but does not include datasets marked 'onhold', 'wontfix' or 'new' in the ES-DOC ERRATA")
    display(table)
    print('\n\n')
